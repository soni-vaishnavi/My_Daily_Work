# %% [markdown]
# 🧩 What is join() in Pandas?
# In Pandas, join() is a DataFrame method used to combine two DataFrames based on their index (row labels) or optionally on a key column.

# %%
import pandas as d
import numpy as n

# %%
courses = d.read_csv("courses.xls")
nov = d.read_csv("reg-month1.xls")
dec = d.read_csv("reg-month2.xls")
student = d.read_csv("students.xls")

# %%
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
student
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
nov
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3

# %%
dec
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %% [markdown]
# reset_index

# %%
#joining nov and dec
regs = d.concat([nov, dec], keys = ['nov','dec']).reset_index() #use ignore_index = merge indexes

# %%
regs
# Out:
#    level_0  level_1  student_id  course_id
# 0      nov        0          23          1
# 1      nov        1          15          5
# 2      nov        2          18          6
# 3      nov        3          23          4
# 4      nov        4          16          9
# 5      nov        5          18          1
# 6      nov        6           1          1
# 7      nov        7           7          8
# 8      nov        8          22          3
# 9      nov        9          15          1
# 10     nov       10          19          4
# 11     nov       11           1          6
# 12     nov       12           7         10
# 13     nov       13          11          7
# 14     nov       14          13          3
# 15     nov       15          24          4
# 16     nov       16          21          1
# 17     nov       17          16          5
# 18     nov       18          23          3
# 19     nov       19          17          7
# 20     nov       20          23          6
# ...

# %%
#regs.loc[('nov', 0):('nov',5)]

# %%
regs.groupby("level_0")["student_id"].count()
# Out:
# level_0
# dec    28
# nov    25
# Name: student_id, dtype: int64

# %%
regs['level_0'].value_counts()
# Out:
# level_0
# dec    28
# nov    25
# Name: count, dtype: int64

# %% [markdown]
# we have to find total sale

# %%
mergedata = regs.merge(courses, on = "course_id", how = 'left')

# %%
mergedata
# Out:
#    level_0  level_1  student_id  course_id       course_name  price
# 0      nov        0          23          1            python   2499
# 1      nov        1          15          5           tableau   2499
# 2      nov        2          18          6          power bi   1899
# 3      nov        3          23          4  machine learning   9999
# 4      nov        4          16          9            plotly    699
# 5      nov        5          18          1            python   2499
# 6      nov        6           1          1            python   2499
# 7      nov        7           7          8            pandas   1099
# 8      nov        8          22          3     data analysis   4999
# 9      nov        9          15          1            python   2499
# 10     nov       10          19          4  machine learning   9999
# 11     nov       11           1          6          power bi   1899
# 12     nov       12           7         10           pyspark   2499
# ...

# %%
mergedata.groupby(["level_0"])["price"].sum()
# Out:
# level_0
# dec    65072
# nov    89175
# Name: price, dtype: int64

# %%
mergedata = regs.merge(courses, on = "course_id", how = 'right')
#just trying

# %%
mergedata
# Out:
#    level_0  level_1  student_id  course_id       course_name  price
# 0      nov      0.0        23.0          1            python   2499
# 1      nov      5.0        18.0          1            python   2499
# 2      nov      6.0         1.0          1            python   2499
# 3      nov      9.0        15.0          1            python   2499
# 4      nov     16.0        21.0          1            python   2499
# 5      nov     21.0        25.0          1            python   2499
# 6      dec      3.0        12.0          1            python   2499
# 7      dec     23.0        14.0          1            python   2499
# 8      dec     27.0        38.0          1            python   2499
# 9      nov     22.0        19.0          2               sql   3499
# 10     dec      6.0         7.0          2               sql   3499
# 11     nov      8.0        22.0          3     data analysis   4999
# 12     nov     14.0        13.0          3     data analysis   4999
# ...

# %%
mergedata2 =courses.merge(regs, on = "course_id", how = 'left')

# %%
mergedata2
# Out:
#     course_id       course_name  price level_0  level_1  student_id
# 0           1            python   2499     nov      0.0        23.0
# 1           1            python   2499     nov      5.0        18.0
# 2           1            python   2499     nov      6.0         1.0
# 3           1            python   2499     nov      9.0        15.0
# 4           1            python   2499     nov     16.0        21.0
# 5           1            python   2499     nov     21.0        25.0
# 6           1            python   2499     dec      3.0        12.0
# 7           1            python   2499     dec     23.0        14.0
# 8           1            python   2499     dec     27.0        38.0
# 9           2               sql   3499     nov     22.0        19.0
# 10          2               sql   3499     dec      6.0         7.0
# 11          3     data analysis   4999     nov      8.0        22.0
# 12          3     data analysis   4999     nov     14.0        13.0
# ...

# %%
mergedata2.groupby(["level_0"])["price"].sum()
# Out:
# level_0
# dec    65072
# nov    89175
# Name: price, dtype: int64

# %%
regs
# Out:
#    level_0  level_1  student_id  course_id
# 0      nov        0          23          1
# 1      nov        1          15          5
# 2      nov        2          18          6
# 3      nov        3          23          4
# 4      nov        4          16          9
# 5      nov        5          18          1
# 6      nov        6           1          1
# 7      nov        7           7          8
# 8      nov        8          22          3
# 9      nov        9          15          1
# 10     nov       10          19          4
# 11     nov       11           1          6
# 12     nov       12           7         10
# 13     nov       13          11          7
# 14     nov       14          13          3
# 15     nov       15          24          4
# 16     nov       16          21          1
# 17     nov       17          16          5
# 18     nov       18          23          3
# 19     nov       19          17          7
# 20     nov       20          23          6
# ...

# %%
regs.head()
# Out:
#   level_0  level_1  student_id  course_id
# 0     nov        0          23          1
# 1     nov        1          15          5
# 2     nov        2          18          6
# 3     nov        3          23          4
# 4     nov        4          16          9

# %%
#finding who paid the highest amount

# %%
mergedata .groupby(["student_id"])['price'].sum().sort_values()
# Out:
# student_id
# 42.0      699
# 50.0     1099
# 2.0      2499
# 38.0     2499
# 21.0     2499
# 17.0     4098
# 15.0     4998
# 25.0     4998
# 13.0     4999
# 11.0     5197
# 18.0     5497
# 3.0      7498
# 1.0      7596
# 12.0     9096
# 22.0     9397
# 16.0     9796
# 24.0     9999
# 7.0     10595
# 19.0    13498
# 14.0    15096
# 23.0    22594
# Name: price, dtype: int64

# %%
student[student["student_id"]==23]
# Out:
#     student_id            name  partner
# 22          23  Chhavi Lachman       18

# %%
student.head(2)
# Out:
#    student_id           name  partner
# 0           1  Kailash Harjo       23
# 1           2    Esha Butala        1

# %%
courses.head(2)
# Out:
#    course_id course_name  price
# 0          1      python   2499
# 1          2         sql   3499

# %%
regs.head(2)
# Out:
#   level_0  level_1  student_id  course_id
# 0     nov        0          23          1
# 1     nov        1          15          5

# %%
mergedata = regs.merge(student, on = "student_id", how = 'left')

# %%
mergedata

# %%
student.head(2)
# Out:
#    student_id           name  partner
# 0           1  Kailash Harjo       23
# 1           2    Esha Butala        1

# %%
student.head(5)
# Out:
#    student_id            name  partner
# 0           1   Kailash Harjo       23
# 1           2     Esha Butala        1
# 2           3  Parveen Bhalla        3
# 3           4     Marlo Dugal       14
# 4           5     Kusum Bahri        6

# %%
lst = []
for i in students[partner]:

# %%
student.head(2)
# Out:
#    student_id           name  partner
# 0           1  Kailash Harjo       23
# 1           2    Esha Butala        1

# %%
megre2 = student.merge(student, left_on = "partner",right_on = "student_id", how = 'inner', suffixes=['_soni','_vaishu'])

# %%
lst = []
for i in student['partner']:
    student

# %%
megre2
# Out:
#     student_id_soni           name_soni  partner_soni  student_id_vaishu  \
# 0                 1       Kailash Harjo            23                 23
# 1                 2         Esha Butala             1                  1
# 2                 3      Parveen Bhalla             3                  3
# 3                 4         Marlo Dugal            14                 14
# 4                 5         Kusum Bahri             6                  6
# 5                 6  Lakshmi Contractor            10                 10
# 6                 7        Tarun Thaker             9                  9
# 7                 8      Radheshyam Dey             5                  5
# 8                 9   Nitika Chatterjee             4                  4
# 9                10      Aayushman Sant             8                  8
# 10               11  David Mukhopadhyay            20                 20
# 11               12          Radha Dutt            19                 19
# ...
