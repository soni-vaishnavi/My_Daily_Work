# %%
import numpy as n
import pandas as d
import matplotlib.pyplot as lt

# %%
who = d.read_csv('WHO.xls')
day = d.read_csv('day.xls')

# %%
who.head()
# Out:
#   Date_reported Country  New_cases  Cumulative_cases  New_deaths  \
# 0    2020-01-04   China          1                 1           0
# 1    2020-01-05   China          0                 1           0
# 2    2020-01-06   China          3                 4           0
# 3    2020-01-07   China          0                 4           0
# 4    2020-01-08   China          0                 4           0
#
#    Cumulative_deaths
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
day.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
#(who.groupby('Country')['New_cases'].sum()).shape

# %%
who.groupby('Country')['New_cases'].sum().iloc[0:10].plot(kind= 'bar')
# Out:
# <Axes: xlabel='Country'>

# %%
#newgraph i also a library for this

# %%
x = n.arange(1,100)
y = x**2
#y=n.sin(x)
lt.plot(x,y, color = '#000000', ls = ':')

lt.title('demo graph')
lt.xlabel('numbers')
lt.ylabel('squares')
lt.figure(figsize=(5,3))

# %%
who.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31876 entries, 0 to 31875
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date_reported      31876 non-null  object
#  1   Country            31876 non-null  object
#  2   New_cases          31876 non-null  int64
#  3   Cumulative_cases   31876 non-null  int64
#  4   New_deaths         31876 non-null  int64
#  5   Cumulative_deaths  31876 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 1.5+ MB

# %%
# studying relationship plot
lt.plot(who['Date_reported'], who['Cumulative_cases'])
# this is the problem 
# so we have to convert the time to date time
who['Date_reported'] = d.to_datetime(who['Date_reported'])

# %%
china = who[who["Country"]=='China']
india = who[who["Country"]=='India']
austria = who[who["Country"]=='Austria']

# %%
lt.plot(china['Date_reported'], china['Cumulative_cases'], color = 'green', label = 'Chine')
lt.plot(india['Date_reported'], india['Cumulative_cases'], label = 'india')
lt.plot(austria['Date_reported'], austria['Cumulative_cases'], label = 'Austria')
lt.legend()
lt.show()
# this is the problem 
# this is the problem

# %%
def func(name):
    
    for i in name:
     nam = who[who["Country"]==i] 
     #or  label = nam
     lt.plot(nam['Date_reported'], nam['Cumulative_cases'], label = i ) #then label = label
     lt.legend()
    lt.show()
    
name = ["India","Austria","China","Japan"]
func(name)

# %%
def func(n, n2):
    name = who[who["Country"]==n]
    name2 = who[who["Country"]==n2]

    lt.plot(name['Date_reported'], name['Cumulative_cases'], color = 'green', label = n)
    lt.plot(name2['Date_reported'], name2['Cumulative_cases'], color = 'blue', label = n2)
    lt.legend()
    lt.show()

func('Japan', 'Austria')

# %% [markdown]
# ## Scatter Plot

# %%
day.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
d.to_datetime(day['dteday'])
# Out:
# 0     2011-01-01
# 1     2011-01-02
# 2     2011-01-03
# 3     2011-01-04
# 4     2011-01-05
#          ...
# 726   2012-12-27
# 727   2012-12-28
# 728   2012-12-29
# 729   2012-12-30
# 730   2012-12-31
# Name: dteday, Length: 731, dtype: datetime64[ns]

# %%
day.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %% [markdown]
# ehre we can see that the values of the temp and atemp lies in between 0 and 1 so it might be normalized already

# %%
day['season'].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
day['yr'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
lt.scatter(day['temp'], day['cnt'], c = day['season'])
lt.colorbar()
lt.xlabel("tempeature")
lt.ylabel('Count')
lt.title('Count VS Temperature')
# Out:
# Text(0.5, 1.0, 'Count VS Temperature')

# %% [markdown]
# we can color the dots according to the vaalue of x or y axis,this work is done by c attribute

# %%
x = n.arange(1, 7)
y = n.array([300,40,50,25,20,70])
lt.scatter(x,y,s= y ,c=y, cmap='Blues') #gieve s = y for changing the size of dots according to the value in y #here c is giving colour according to the sequence

lt.colorbar()
#lt.text(3,5 , s= '(3,5)')
for i in range(len(x)):
        lt.text(x[i],y[i] , s =f"({x[i]}, {y[i]})")

# %% [markdown]
# checking the value of season as where 1 lie in which month

# %%
day[['season', 'mnth']].sort_values('season')
(day[['season', 'mnth']].sort_values('season') == 1)
# Out:
#      season   mnth
# 0      True   True
# 382    True   True
# 383    True   True
# 384    True   True
# 385    True   True
# ..      ...    ...
# 326   False  False
# 327   False  False
# 328   False  False
# 308   False  False
# 339   False  False
#
# [731 rows x 2 columns]

# %% [markdown]
# 23/06/25

# %%
day['temp'].corr(day['cnt'])
# Out:
# 0.6274940090334917

# %%
day.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
day['dteday'] = d.to_datetime(day['dteday'])

# %%
day.corr()['workingday'][['casual', 'registered']]
# Out:
# casual       -0.518044
# registered    0.303907
# Name: workingday, dtype: float64

# %%
#day['workingday'].corr()[['casual', 'registered']]  #wrong syntax

# %%
lt.scatter(day['workingday'],day['cnt'])

# %% [markdown]
# as working day is a categorical data.....we are seeing this kind of graph.

# %% [markdown]
# # now working with the Comparison type of data.

# %%
day['season']= day['season'].astype('category')

# %%
day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    category
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: category(1), datetime64[ns](1), float64(4), int64(10)
# memory usage: 86.7 KB

# %%
lt.bar(day['season'], day['cnt'])
lt.xticks( labels = ['a','b','c','d'], rotation = 30, ticks = [1,2,3,4])
lt.show()

# %%
x = day.groupby(['season'], observed= False)['cnt'].mean()

# %%
lt.bar(x.index, x.values)
# Out:
# <BarContainer object of 4 artists>

# %%
#this is wrong as it is causing so many overlaps of data
lt.bar(day['workingday'], day['cnt'])
lt.xticks(ticks = [0,1], rotation = 30, labels=['holiday','workingday'])
# Out:
# ([<matplotlib.axis.XTick at 0x27a3c32c380>,
# ...
#  [Text(0, 0, 'holiday'), Text(1, 0, 'workingday')])

# %%
grouped = day.groupby('workingday')['cnt'].sum()
lt.bar(['Holiday', 'Working Day'], grouped, color=['red','blue'])
# Out:
# <BarContainer object of 2 artists>

# %%
x = day.groupby('season', observed=False)[['registered', 'casual']].sum()
day.groupby('season', observed=False)[['registered', 'casual']].sum().plot(kind = 'bar')
# Out:
# <Axes: xlabel='season'>

# %%
bar1 = n.array([30,40,50,60])
bar2 = n.array([15,25,35,45])
x = n.arange(1,5)

lt.bar(x, bar1, width = .25)
lt.bar(x+0.25, bar2, width = .25)
lt.xticks(ticks = [1,2,3,4])
# Out:
# ([<matplotlib.axis.XTick at 0x27a3bb82960>,
# ...
#  [Text(1, 0, '1'), Text(2, 0, '2'), Text(3, 0, '3'), Text(4, 0, '4')])

# %% [markdown]
# Manyata way .....though ....converted the seasons into array

# %%
barwidth = 0.25

# %%
x = n.array(day['season'])

# %%
lt.bar(x, day['registered'],width=barwidth)
lt.bar(x+barwidth, day['casual'], width=0.25)
lt.bar(x+barwidth+barwidth, day['cnt'], width=0.25)
# Out:
# <BarContainer object of 731 artists>

# %% [markdown]
# My way

# %%
day['weekday'].unique()
# Out:
# array([6, 0, 1, 2, 3, 4, 5], dtype=int64)

# %%
grouped = day.groupby('season')['registered'].sum()
grouped2 = day.groupby('season')['casual'].sum()
grouped3 = day.groupby('season')['cnt'].sum()
seasons = n.array([1, 2, 3, 4])

lt.bar(seasons, grouped, width=0.25)
lt.bar(seasons+0.25, grouped2,0.25)
lt.bar(seasons+0.5, grouped3,0.25)
lt.xticks(ticks = [1,2,3,4], labels =[1,2,3,4])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_18916\2423248330.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = day.groupby('season')['registered'].sum()
# C:\Users\Dell\AppData\Local\Temp\ipykernel_18916\2423248330.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped2 = day.groupby('season')['casual'].sum()
# ...

# %%
day.head()
# Out:
#    instant     dteday season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2011-01-01      1   0     1        0        6           0
# 1        2 2011-01-02      1   0     1        0        0           0
# 2        3 2011-01-03      1   0     1        0        1           1
# 3        4 2011-01-04      1   0     1        0        2           1
# 4        5 2011-01-05      1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
groupedd = day.groupby('weekday')['registered'].sum()
groupedd2 = day.groupby('weekday')['casual'].sum()
groupedd3 = day.groupby('weekday')['cnt'].sum()
seasons = n.array([0,1, 2, 3, 4,5,6])

lt.bar(seasons, groupedd, width=0.25)
lt.bar(seasons+0.25, groupedd2,0.25)
lt.bar(seasons+0.5, groupedd3,0.25)
lt.xticks(ticks = [0,1,2,3,4,5,6], labels =[0,1,2,3,4,5,6])
# Out:
# ([<matplotlib.axis.XTick at 0x27a3d6a20f0>,
# ...
#  [Text(0, 0, '0'),
#   Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6')])

# %% [markdown]
# ## 24/6/25  creating subplots

# %%
lt.subplot(2,2,1)
lt.plot(bar1, bar2, color = 'red', ls = ':')
lt.title('First')

lt.subplot(2,2,4)
lt.plot(bar1, bar2, color = 'green', ls = ':')
lt.title('Second')
# Out:
# Text(0.5, 1.0, 'Second')

# %%
who['Country'].unique()
# Out:
# array(['China', 'Thailand', 'Japan', 'Republic of Korea',
#        'United States of America', 'Singapore', 'Nepal', 'France',
#        'Viet Nam', 'Malaysia', 'Australia', 'Canada', 'Sri Lanka',
#        'Cambodia', 'Germany', 'Italy', 'Finland', 'United Arab Emirates',
#        'India', 'Philippines', 'Sweden', 'Russian Federation',
#        'The United Kingdom', 'Spain', 'Belgium', 'Other', 'Egypt',
#        'Iran (Islamic Republic of)', 'Israel', 'Lebanon', 'Oman',
#        'Bahrain', 'Switzerland', 'Iraq', 'Afghanistan', 'Kuwait',
#        'Algeria', 'Austria', 'Romania', 'Norway', 'North Macedonia',
#        'Croatia', 'Georgia', 'Pakistan', 'Brazil', 'Denmark', 'Greece',
#        'Estonia', 'Nigeria', 'Lithuania', 'New Zealand', 'Mexico',
#        'Netherlands', 'San Marino', 'Ecuador', 'Monaco', 'Qatar',
#        'Azerbaijan', 'Belarus', 'Armenia', 'Czechia', 'Ireland',
#        'Iceland', 'Luxembourg', 'Morocco', 'Saint Barthélemy', 'Portugal',
# ...

# %%
who.head()
# Out:
#   Date_reported Country  New_cases  Cumulative_cases  New_deaths  \
# 0    2020-01-04   China          1                 1           0
# 1    2020-01-05   China          0                 1           0
# 2    2020-01-06   China          3                 4           0
# 3    2020-01-07   China          0                 4           0
# 4    2020-01-08   China          0                 4           0
#
#    Cumulative_deaths
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
g1= who.groupby('Country')['New_cases'].value_counts()

# %%
china = who[who["Country"]=='China']
india = who[who["Country"]=='India']
austria = who[who["Country"]=='Austria']

# %%
fig=lt.figure(figsize = (16,10))
fig.tight_layout()
lt.subplot(2,2,1)
lt.plot(china['Date_reported'], china['Cumulative_cases'])
lt.title('China')
lt.subplot(2,2,2)
lt.plot(india['Date_reported'], india['Cumulative_cases'])
lt.title('India')
lt.subplot(2,2,4)
lt.plot(austria['Date_reported'], austria['Cumulative_cases'])
lt.title('austria')
# Out:
# Text(0.5, 1.0, 'austria')

# %%
# i wanted to do it this way....
# Group all countries first
# all_grouped = who.groupby('Country')['New_cases'].sum()

# # Filter using .loc[]
# selected_group = all_grouped.loc[['China', 'India', 'Austria']]
# print(selected_group)

# %%
fig, axes = lt.subplots(3,2)
axes[0,0].plot(bar1, bar2)
axes[0,0].set_title('first')

axes[2,1].bar(bar1, bar2)
axes[2,1].set_title('third')

axes[1,1].scatter(bar1, bar2)
axes[1,1].set_title('second')

lt.show()

# %% [markdown]
# ## Distribution Plot
# ### Histogram

# %%
day.head()
# Out:
#    instant     dteday season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2011-01-01      1   0     1        0        6           0
# 1        2 2011-01-02      1   0     1        0        0           0
# 2        3 2011-01-03      1   0     1        0        1           1
# 3        4 2011-01-04      1   0     1        0        2           1
# 4        5 2011-01-05      1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# Q1. how many cycles he will take to new city in new store?

# %%
lt.subplot(3,3,1)
lt.hist(day['cnt'], bins=40)
lt.axvline(day['cnt'].mean(), color = 'red')
lt.axvline(4000, color = 'red')
lt.title('Count')

lt.subplot(3,3,2)
lt.hist(day['registered'], bins=40)
lt.axvline(day['registered'].mean(), color = 'red')
lt.axvline(4000, color = 'red')
lt.title('Registered')

lt.subplot(3,3,3)
lt.hist(day['casual'], bins=40)
lt.axvline(day['casual'].mean(), color = 'red')
lt.axvline(4000, color = 'red')
lt.title('Casual')

lt.subplot(3,3,4)
lt.hist(day['windspeed'], bins=40, density= True)
lt.axvline(day['windspeed'].mean(), color = 'red')
lt.title('Windspeed')

lt.subplot(3,3,5)
lt.hist(day['temp'], bins=40, density= True)
lt.axvline(day['temp'].mean(), color = 'red')
lt.title('temp')


lt.subplot(3,3,6)
lt.hist(day['atemp'], bins=40, density= True)
lt.axvline(day['atemp'].mean(), color = 'red')
lt.title('atemp')

lt.subplot(3,3,7)
lt.scatter(day['temp'], day['cnt'], alpha=0.5, c=day['cnt'] )
lt.axhline(day['cnt'].mean(), color='red')
lt.axvline(day['temp'].mean(), color='green')
lt.xlabel('Temperature')
lt.ylabel('Cycle Count')

lt.subplot(3,3,8)
lt.scatter(day['windspeed'], day['cnt'], alpha=0.5, c=day['cnt'])
lt.colorbar()
lt.xlabel('Windspeed')
lt.ylabel('Cycle Count')

lt.tight_layout()
lt.show()

# %%
day['cnt'].mean()
# Out:
# 4504.3488372093025

# %%
day.head()
# Out:
#    instant     dteday season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2011-01-01      1   0     1        0        6           0
# 1        2 2011-01-02      1   0     1        0        0           0
# 2        3 2011-01-03      1   0     1        0        1           1
# 3        4 2011-01-04      1   0     1        0        2           1
# 4        5 2011-01-05      1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
#ie savefig, exlode
