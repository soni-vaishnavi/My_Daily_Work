# %%
import numpy as n
import pandas as d
import matplotlib.pyplot as lt
import seaborn as sns

# %% [markdown]
# ## about data
#
# age: (numeric)
#
# job: type of job (categorical: 'admin','blue collar','entrepreneur','housemaid','management','retired','self employed','services','student','technician','unemployed','unknown')
#
# marital: marital status (categorical: 'divorced','married','single','unknown'; note: 'divorced' means divorced or widowed)
#
# education: (categorical: 'basic.4y','basic.6y','basic.9y','high.school','illiterate','professional.course','university.degree','unknown')
#
# default: has credit in default? (categorical: 'no','yes','unknown')
#
# housing: has housing loan? (categorical: 'no','yes','unknown')
#
# loan: has personal loan? (categorical: 'no','yes','unknown')
#
# contact: contact communication type (categorical: 'cellular','telephone')
#
# month: last contact month of year (categorical: 'jan', 'feb', 'mar', ..., 'nov', 'dec')
#
# day_of_week: last contact day of the week (categorical: 'mon','tue','wed','thu','fri')
#
# duration: last contact duration, in seconds (numeric).
#
# campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#
# pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
#
# previous: number of contacts performed before this campaign and for this client (numeric)
#
# poutcome: outcome of the previous marketing campaign (categorical: 'failure','nonexistent','success')
#
# emp.var.rate: employment variation rate - quarterly indicator (numeric)
#
# cons.price.idx: consumer price index - monthly indicator (numeric)
#
# cons.conf.idx: consumer confidence index - monthly indicator (numeric)
#
# euribor3m: euribor 3 month rate - daily indicator (numeric)
#
# nr.employed: number of employees - quarterly indicator (nume

# %%
df = d.read_csv("subscription_prediction (1).xls")

# %%
d.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    age          job   marital    education  default housing loan    contact  \
# 0   40       admin.   married     basic.6y       no      no   no  telephone
# 1   56     services   married  high.school       no      no  yes  telephone
# 2   41  blue-collar   married      unknown  unknown      no   no  telephone
# 3   57    housemaid  divorced     basic.4y       no     yes   no  telephone
# 4   39   management    single     basic.9y  unknown      no   no  telephone
#
#   month day_of_week  duration  campaign  pdays  previous     poutcome  \
# 0   may         mon       151         1    999         0  nonexistent
# 1   may         mon       307         1    999         0  nonexistent
# 2   may         mon       217         1    999         0  nonexistent
# 3   may         mon       293         1    999         0  nonexistent
# 4   may         mon       195         1    999         0  nonexistent
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
df['y']= df['y'].apply(lambda x:1 if x=='yes' else 0)

# %%
df['y'].unique(), df.shape, df['y'].value_counts()
# Out:
# (array([0, 1], dtype=int64),
#  (10122, 21),
#  y
#  0    5482
#  1    4640
#  Name: count, dtype: int64)

# %%
df.dtypes.value_counts()
# Out:
# object     10
# int64       6
# float64     5
# Name: count, dtype: int64

# %%
(df.dtypes=='object').value_counts()
# Out:
# False    11
# True     10
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.select_dtypes('object')
# Out:
#                job   marital            education  default housing loan  \
# 0           admin.   married             basic.6y       no      no   no
# 1         services   married          high.school       no      no  yes
# 2      blue-collar   married              unknown  unknown      no   no
# 3        housemaid  divorced             basic.4y       no     yes   no
# 4       management    single             basic.9y  unknown      no   no
# ...            ...       ...                  ...      ...     ...  ...
# 10117      retired  divorced  professional.course       no     yes   no
# 10118       admin.   married    university.degree       no     yes   no
# 10119      retired   married  professional.course       no     yes   no
# 10120   technician   married  professional.course       no      no   no
# 10121      retired   married  professional.course       no     yes   no
#
#          contact month day_of_week     poutcome
# 0      telephone   may         mon  nonexistent
# ...

# %%
traindata = df.sample(int(len(df)*.80), random_state=37)

# %%
traindata.shape
# Out:
# (8097, 21)

# %%
traindata.head()
# Out:
#       age         job   marital          education default housing loan  \
# 7982   33      admin.    single        high.school      no     yes   no
# 9371   28  management    single  university.degree      no     yes   no
# 9060   59      admin.  divorced  university.degree      no     yes   no
# 114    40      admin.  divorced  university.degree      no     yes   no
# 6915   29      admin.    single        high.school      no     yes   no
#
#         contact month day_of_week  duration  campaign  pdays  previous  \
# 7982   cellular   aug         fri      1088         3    999         0
# 9371   cellular   jun         thu       383         1     22         1
# 9060   cellular   mar         tue       236         1    999         0
# 114   telephone   may         tue       189         3    999         0
# 6915   cellular   may         wed       149         1    999         1
#
#          poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
testdata= df.drop(traindata.index)

# %%
testdata.shape
# Out:
# (2025, 21)

# %%
print(traindata['y'].value_counts(normalize=True),
testdata['y'].value_counts(normalize=True))
# Out:
# y
# 0    0.541435
# 1    0.458565
# Name: proportion, dtype: float64 y
# 0    0.542222
# 1    0.457778
# Name: proportion, dtype: float64

# %%
X_train=traindata.drop("y",axis=1)
y_train=traindata["y"]

# %%
X_test=testdata.drop("y",axis=1)
y_test=testdata["y"]

# %%
5851,4325,7472

# %%
def my_knn(feature_name,single_input,k):
    distance=X_train[feature_name]-single_input[feature_name]
    print(abs(distance.sort_values(ascending=True)[0:20]))
    print("#########################################")
    smallest_distance=distance.nsmallest(k)
    print(smallest_distance)
    print("#########################################")
    smallest_index=smallest_distance.index
    print(smallest_index)
    print("#########################################")
    prediction=y_train[smallest_index].mode()
    print(prediction)
    print("#########################################")
    return prediction

# %%
my_knn("age",X_test.iloc[22],5)
# Out:
# 8452     26
# 8126     26
# 9665     25
# 8744     25
# 8276     25
# 8861     25
# 8296     25
# 10061    25
# 9184     25
# 8326     25
# 7932     25
# 7397     25
# 8143     25
# 9662     25
# 5724     24
# 8760     24
# 5499     24
# 5382     24
# 5824     24
# 9763     24
# Name: age, dtype: int64
# #########################################
# 8126    -26
# 8452    -26
# 8143    -25
# 8744    -25
# 10061   -25
# Name: age, dtype: int64
# #########################################
# Index([8126, 8452, 8143, 8744, 10061], dtype='int64')
# #########################################
# 0    1
# Name: y, dtype: int64
# #########################################
# 0    1
# Name: y, dtype: int64
