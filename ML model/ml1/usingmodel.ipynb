# %%
import numpy as n
import pandas as d
import matplotlib.pyplot as lt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler

# %%
df = d.read_csv("subscription_prediction (1).xls")

# %%
df.head()
# Out:
#    age          job   marital    education  default housing loan    contact  \
# 0   40       admin.   married     basic.6y       no      no   no  telephone
# 1   56     services   married  high.school       no      no  yes  telephone
# 2   41  blue-collar   married      unknown  unknown      no   no  telephone
# 3   57    housemaid  divorced     basic.4y       no     yes   no  telephone
# 4   39   management    single     basic.9y  unknown      no   no  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.shape
# Out:
# (10122, 21)

# %%
df['y']=df['y'].apply(lambda x : 1 if x =='yes' else 0)

# %%
df['y'].value_counts()
# Out:
# y
# 0    5482
# 1    4640
# Name: count, dtype: int64

# %%
X = df.drop('y', axis=1)
y = df['y']
Xtrain, Xtest, ytrain, ytest = train_test_split(X,y, train_size=0.6, random_state=417)

# %%
Xtest.shape
# Out:
# (4049, 20)

# %% [markdown]
# train test and validate split

# %%
Xtest,xval,ytest, yval = train_test_split(Xtest, ytest, train_size=0.5, random_state=417)

# %%
Xtest.shape
# Out:
# (2024, 20)

# %%
xval.shape
# Out:
# (2025, 20)

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
# knn.fit(Xtrain, ytrain)  this will show an error as knn defined on numerical data...and there are so many strings columns in the training data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10122 entries, 0 to 10121
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             10122 non-null  int64
#  1   job             10122 non-null  object
#  2   marital         10122 non-null  object
#  3   education       10122 non-null  object
#  4   default         10122 non-null  object
#  5   housing         10122 non-null  object
#  6   loan            10122 non-null  object
#  7   contact         10122 non-null  object
#  8   month           10122 non-null  object
#  9   day_of_week     10122 non-null  object
#  10  duration        10122 non-null  int64
#  11  campaign        10122 non-null  int64
#  12  pdays           10122 non-null  int64
#  13  previous        10122 non-null  int64
#  14  poutcome        10122 non-null  object
#  15  emp.var.rate    10122 non-null  float64
#  16  cons.price.idx  10122 non-null  float64
# ...

# %%
xtrainscaled=d.get_dummies(Xtrain, columns=['marital', 'education'], drop_first= True)

# %%
xtrainscaled
# Out:
#       age            job  default housing loan    contact month day_of_week  \
# 5725   38     management  unknown     yes   no   cellular   apr         fri
# 2201   43  self-employed  unknown     yes   no  telephone   jun         tue
# 8962   36         admin.       no      no   no   cellular   mar         mon
# 156    32     technician       no      no   no  telephone   may         wed
# 4405   37     technician       no      no   no   cellular   aug         tue
# ...   ...            ...      ...     ...  ...        ...   ...         ...
# 8270   54         admin.       no     yes   no   cellular   sep         tue
# 4717   43     management       no     yes   no   cellular   nov         tue
# 4263   31     technician  unknown     yes   no   cellular   aug         fri
# 7009   29         admin.       no     yes   no   cellular   may         wed
# 2617   32         admin.       no      no   no   cellular   jul         mon
#
# ...

# %%
xtrainscaled=xtrainscaled[['age','marital_married', 'pdays']]

# %%
xtrainscaled.head()
# Out:
#       age  marital_married  pdays
# 5725   38             True    999
# 2201   43            False    999
# 8962   36            False    999
# 156    32            False    999
# 4405   37            False    999

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(xtrainscaled)
# Out:
# MinMaxScaler()

# %%
scaler.min_
# Out:
# array([-0.22666667,  0.        ,  0.        ])

# %%
n1 = scaler.transform(xtrainscaled)

# %%
n1
d2=d.DataFrame(n1,columns=xtrainscaled.columns)
d2.head()
# Out:
#         age  marital_married  pdays
# 0  0.280000              1.0    1.0
# 1  0.346667              0.0    1.0
# 2  0.253333              0.0    1.0
# 3  0.200000              0.0    1.0
# 4  0.266667              0.0    1.0

# %% [markdown]
# now working with xval to scale it

# %%
Xtest.head()
Xvalscaled=d.get_dummies(xval,columns=["marital","education"],drop_first=True)
Xvalscaled=Xvalscaled[["age","marital_married","pdays"]]
Xvalscaled=scaler.transform(Xvalscaled)

# %%
Xvalscaled[0:3]
# Out:
# array([[0.48      , 1.        , 1.        ],
#        [0.22666667, 1.        , 1.        ],
#        [0.50666667, 0.        , 1.        ]])

# %%
knn=KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(d2,ytrain)
# Out:
# KNeighborsClassifier()

# %%
knn.predict(Xvalscaled)
# Out:
# c:\Users\Dell\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([1, 0, 0, ..., 0, 1, 1], dtype=int64)

# %%
knn.score(Xvalscaled,yval)
# Out:
# c:\Users\Dell\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 0.6172839506172839
